# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
test_df = pd.read_csv("test.csv")
train_df = pd.read_csv("train.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
print("(No of rows, No of Columns) = ",train_df.shape)
train_df.head()
# Out:
# (No of rows, No of Columns) =  (1460, 81)
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
for i in range(0,1460):
  if(train_df['FireplaceQu'][i]=='Ex'):
    train_df['FireplaceQu'][i]=100
  elif(train_df['FireplaceQu'][i]=='Gd'):
    train_df['FireplaceQu'][i]=80
  elif(train_df['FireplaceQu'][i]=='TA'):
    train_df['FireplaceQu'][i]=60
  elif(train_df['FireplaceQu'][i]=='Fa'):
    train_df['FireplaceQu'][i]=40
  elif(train_df['FireplaceQu'][i]=='NaN'):
    train_df['FireplaceQu'][i]=0
  elif(train_df['FireplaceQu'][i]=='Po'):
    train_df['FireplaceQu'][i]=20


for i in range(0,1459):
  if(test_df['FireplaceQu'][i]=='Ex'):
    test_df['FireplaceQu'][i]=100
  elif(test_df['FireplaceQu'][i]=='Gd'):
    test_df['FireplaceQu'][i]=80
  elif(test_df['FireplaceQu'][i]=='TA'):
    test_df['FireplaceQu'][i]=60
  elif(test_df['FireplaceQu'][i]=='Fa'):
    test_df['FireplaceQu'][i]=40
  elif(test_df['FireplaceQu'][i]=='NaN'):
    test_df['FireplaceQu'][i]=0
  elif(test_df['FireplaceQu'][i]=='Po'):
    test_df['FireplaceQu'][i]=20


for i in range(0,1460):
  if(train_df['KitchenQual'][i]=='Ex'):
    train_df['KitchenQual'][i]=100
  elif(train_df['KitchenQual'][i]=='Gd'):
    train_df['KitchenQual'][i]=80
  elif(train_df['KitchenQual'][i]=='TA'):
    train_df['KitchenQual'][i]=60
  elif(train_df['KitchenQual'][i]=='Fa'):
    train_df['KitchenQual'][i]=40
  elif(train_df['KitchenQual'][i]=='Po'):
    train_df['KitchenQual'][i]=20


for i in range(0,1459):
  if(test_df['KitchenQual'][i]=='Ex'):
    test_df['KitchenQual'][i]=100
  elif(test_df['KitchenQual'][i]=='Gd'):
    test_df['KitchenQual'][i]=80
  elif(test_df['KitchenQual'][i]=='TA'):
    test_df['KitchenQual'][i]=60
  elif(test_df['KitchenQual'][i]=='Fa'):
    test_df['KitchenQual'][i]=40
  elif(test_df['KitchenQual'][i]=='Po'):
    test_df['KitchenQual'][i]=20

for i in range(0,1460):
  if(train_df['HeatingQC'][i]=='Ex'):
    train_df['HeatingQC'][i]=100
  elif(train_df['HeatingQC'][i]=='Gd'):
    train_df['HeatingQC'][i]=80
  elif(train_df['HeatingQC'][i]=='TA'):
    train_df['HeatingQC'][i]=60
  elif(train_df['HeatingQC'][i]=='Fa'):
    train_df['HeatingQC'][i]=40
  elif(train_df['HeatingQC'][i]=='Po'):
    train_df['HeatingQC'][i]=20


for i in range(0,1459):
  if(test_df['HeatingQC'][i]=='Ex'):
    test_df['HeatingQC'][i]=100
  elif(test_df['HeatingQC'][i]=='Gd'):
    test_df['HeatingQC'][i]=80
  elif(test_df['HeatingQC'][i]=='TA'):
    test_df['HeatingQC'][i]=60
  elif(test_df['HeatingQC'][i]=='Fa'):
    test_df['HeatingQC'][i]=40
  elif(test_df['HeatingQC'][i]=='Po'):
    test_df['HeatingQC'][i]=20

for i in range(0,1460):
  if(train_df['CentralAir'][i]=='Y'):
    train_df['CentralAir'][i]=100
  elif(train_df['CentralAir'][i]=='N'):
    train_df['CentralAir'][i]=0

for i in range(0,1459):
  if(test_df['CentralAir'][i]=='Y'):
    test_df['CentralAir'][i]=100
  elif(test_df['CentralAir'][i]=='N'):
    test_df['CentralAir'][i]=0


for i in range(0,1460):
  if(train_df['GarageFinish'][i]=='Fin'):
    train_df['GarageFinish'][i]=100
  elif(train_df['GarageFinish'][i]=='RFn'):
    train_df['GarageFinish'][i]=80
  elif(train_df['GarageFinish'][i]=='Unf'):
    train_df['GarageFinish'][i]=40
  elif(train_df['GarageFinish'][i]=='NaN'):
    train_df['GarageFinish'][i]=0



for i in range(0,1459):
  if(test_df['GarageFinish'][i]=='Fin'):
    test_df['GarageFinish'][i]=100
  elif(test_df['GarageFinish'][i]=='RFn'):
    test_df['GarageFinish'][i]=80
  elif(test_df['GarageFinish'][i]=='Unf'):
    test_df['GarageFinish'][i]=40
  elif(test_df['GarageFinish'][i]=='NaN'):
    test_df['GarageFinish'][i]=0


for i in range(0,1460):
  if(train_df['ExterQual'][i]=='Ex'):
    train_df['ExterQual'][i]=100
  elif(train_df['ExterQual'][i]=='Gd'):
    train_df['ExterQual'][i]=80
  elif(train_df['ExterQual'][i]=='TA'):
    train_df['ExterQual'][i]=60
  elif(train_df['ExterQual'][i]=='Fa'):
    train_df['ExterQual'][i]=40
  elif(train_df['ExterQual'][i]=='Po'):
    train_df['ExterQual'][i]=20


for i in range(0,1459):
  if(test_df['ExterQual'][i]=='Ex'):
    test_df['ExterQual'][i]=100
  elif(test_df['ExterQual'][i]=='Gd'):
    test_df['ExterQual'][i]=80
  elif(test_df['ExterQual'][i]=='TA'):
    test_df['ExterQual'][i]=60
  elif(test_df['ExterQual'][i]=='Fa'):
    test_df['ExterQual'][i]=40
  elif(test_df['ExterQual'][i]=='Po'):
    test_df['ExterQual'][i]=20


for i in range(0,1460):
  if(train_df['ExterCond'][i]=='Ex'):
    train_df['ExterCond'][i]=100
  elif(train_df['ExterCond'][i]=='Gd'):
    train_df['ExterCond'][i]=80
  elif(train_df['ExterCond'][i]=='TA'):
    train_df['ExterCond'][i]=60
  elif(train_df['ExterCond'][i]=='Fa'):
    train_df['ExterCond'][i]=40
  elif(train_df['ExterCond'][i]=='Po'):
    train_df['ExterCond'][i]=20


for i in range(0,1459):
  if(test_df['ExterCond'][i]=='Ex'):
    test_df['ExterCond'][i]=100
  elif(test_df['ExterCond'][i]=='Gd'):
    test_df['ExterCond'][i]=80
  elif(test_df['ExterCond'][i]=='TA'):
    test_df['ExterCond'][i]=60
  elif(test_df['ExterCond'][i]=='Fa'):
    test_df['ExterCond'][i]=40
  elif(test_df['ExterCond'][i]=='Po'):
    test_df['ExterCond'][i]=20


for i in range(0,1460):
  if(train_df['BsmtQual'][i]=='Ex'):
    train_df['BsmtQual'][i]=100
  elif(train_df['BsmtQual'][i]=='Gd'):
    train_df['BsmtQual'][i]=80
  elif(train_df['BsmtQual'][i]=='TA'):
    train_df['BsmtQual'][i]=60
  elif(train_df['BsmtQual'][i]=='Fa'):
    train_df['BsmtQual'][i]=40
  elif(train_df['BsmtQual'][i]=='Po'):
    train_df['BsmtQual'][i]=20
  elif(train_df['BsmtQual'][i]=='NaN'):
    train_df['BsmtQual'][i]=0


for i in range(0,1459):
  if(test_df['BsmtQual'][i]=='Ex'):
    test_df['BsmtQual'][i]=100
  elif(test_df['BsmtQual'][i]=='Gd'):
    test_df['BsmtQual'][i]=80
  elif(test_df['BsmtQual'][i]=='TA'):
    test_df['BsmtQual'][i]=60
  elif(test_df['BsmtQual'][i]=='Fa'):
    test_df['BsmtQual'][i]=40
  elif(test_df['BsmtQual'][i]=='Po'):
    test_df['BsmtQual'][i]=20
  elif(test_df['BsmtQual'][i]=='NaN'):
    test_df['BsmtQual'][i]=0


for i in range(1460):
    if train_df['BsmtExposure'][i] == 'Gd':
        train_df['BsmtExposure'][i] = 100
    elif train_df['BsmtExposure'][i] == 'Av':
        train_df['BsmtExposure'][i] = 80
    elif train_df['BsmtExposure'][i] == 'Mn':
        train_df['BsmtExposure'][i] = 60
    elif train_df['BsmtExposure'][i] == 'No':
        train_df['BsmtExposure'][i] = 40
    elif pd.isnull(train_df['BsmtExposure'][i]):
        train_df['BsmtExposure'][i] = 0

# Replace values in 'BsmtExposure' column for the test set
for i in range(1459):
    if test_df['BsmtExposure'][i] == 'Gd':
        test_df['BsmtExposure'][i] = 100
    elif test_df['BsmtExposure'][i] == 'Av':
        test_df['BsmtExposure'][i] = 80
    elif test_df['BsmtExposure'][i] == 'Mn':
        test_df['BsmtExposure'][i] = 60
    elif test_df['BsmtExposure'][i] == 'No':
        test_df['BsmtExposure'][i] = 40
    elif pd.isnull(test_df['BsmtExposure'][i]):
        test_df['BsmtExposure'][i] = 0


for i in range(1460):
    if train_df['BsmtFinType1'][i] == 'GLQ':
        train_df['BsmtFinType1'][i] = 100
    elif train_df['BsmtFinType1'][i] == 'ALQ':
        train_df['BsmtFinType1'][i] = 80
    elif train_df['BsmtFinType1'][i] == 'BLQ':
        train_df['BsmtFinType1'][i] = 60
    elif train_df['BsmtFinType1'][i] == 'Rec':
        train_df['BsmtFinType1'][i] = 40
    elif train_df['BsmtFinType1'][i] == 'LwQ':
        train_df['BsmtFinType1'][i] = 20
    elif pd.isnull(train_df['BsmtFinType1'][i]):
        train_df['BsmtFinType1'][i] = 0

# Replace values in 'BsmtFinType1' column for the test set
for i in range(1459):
    if test_df['BsmtFinType1'][i] == 'GLQ':
        test_df['BsmtFinType1'][i] = 100
    elif test_df['BsmtFinType1'][i] == 'ALQ':
        test_df['BsmtFinType1'][i] = 80
    elif test_df['BsmtFinType1'][i] == 'BLQ':
        test_df['BsmtFinType1'][i] = 60
    elif test_df['BsmtFinType1'][i] == 'Rec':
        test_df['BsmtFinType1'][i] = 40
    elif test_df['BsmtFinType1'][i] == 'LwQ':
        test_df['BsmtFinType1'][i] = 20
    elif pd.isnull(test_df['BsmtFinType1'][i]):
        test_df['BsmtFinType1'][i] = 0

for i in range(1460):
    if train_df['BsmtFinType2'][i] == 'GLQ':
        train_df['BsmtFinType2'][i] = 100
    elif train_df['BsmtFinType2'][i] == 'ALQ':
        train_df['BsmtFinType2'][i] = 80
    elif train_df['BsmtFinType2'][i] == 'BLQ':
        train_df['BsmtFinType2'][i] = 60
    elif train_df['BsmtFinType2'][i] == 'Rec':
        train_df['BsmtFinType2'][i] = 40
    elif train_df['BsmtFinType2'][i] == 'LwQ':
        train_df['BsmtFinType2'][i] = 20
    elif pd.isnull(train_df['BsmtFinType2'][i]):
        train_df['BsmtFinType2'][i] = 0

# Replace values in 'BsmtFinType2' column for the test set
for i in range(1459):
    if test_df['BsmtFinType2'][i] == 'GLQ':
        test_df['BsmtFinType2'][i] = 100
    elif test_df['BsmtFinType2'][i] == 'ALQ':
        test_df['BsmtFinType2'][i] = 80
    elif test_df['BsmtFinType2'][i] == 'BLQ':
        test_df['BsmtFinType2'][i] = 60
    elif test_df['BsmtFinType2'][i] == 'Rec':
        test_df['BsmtFinType2'][i] = 40
    elif test_df['BsmtFinType2'][i] == 'LwQ':
        test_df['BsmtFinType2'][i] = 20
    elif pd.isnull(test_df['BsmtFinType2'][i]):
        test_df['BsmtFinType2'][i] = 0

for i in range(1460):
    if train_df['Heating'][i] == 'GasA':
        train_df['Heating'][i] = 100
    elif train_df['Heating'][i] == 'GasW':
        train_df['Heating'][i] = 80
    elif train_df['Heating'][i] == 'Grav':
        train_df['Heating'][i] = 60
    elif train_df['Heating'][i] == 'Wall':
        train_df['Heating'][i] = 40
    elif train_df['Heating'][i] == 'OthW':
        train_df['Heating'][i] = 20
    elif train_df['Heating'][i] == 'Floor':
        train_df['Heating'][i] = 10

# Replace values in 'Heating' column for the test set
for i in range(1459):
    if test_df['Heating'][i] == 'GasA':
        test_df['Heating'][i] = 100
    elif test_df['Heating'][i] == 'GasW':
        test_df['Heating'][i] = 80
    elif test_df['Heating'][i] == 'Grav':
        test_df['Heating'][i] = 60
    elif test_df['Heating'][i] == 'Wall':
        test_df['Heating'][i] = 40
    elif test_df['Heating'][i] == 'OthW':
        test_df['Heating'][i] = 20
    elif test_df['Heating'][i] == 'Floor':
        test_df['Heating'][i] = 10

for i in range(1460):
    if train_df['Electrical'][i] == 'SBrkr':
        train_df['Electrical'][i] = 100
    elif train_df['Electrical'][i] == 'FuseA':
        train_df['Electrical'][i] = 80
    elif train_df['Electrical'][i] == 'FuseF':
        train_df['Electrical'][i] = 60
    elif train_df['Electrical'][i] == 'FuseP':
        train_df['Electrical'][i] = 40
    elif train_df['Electrical'][i] == 'Mix':
        train_df['Electrical'][i] = 20

# Replace values in 'Electrical' column for the test set
for i in range(1459):
    if test_df['Electrical'][i] == 'SBrkr':
        test_df['Electrical'][i] = 100
    elif test_df['Electrical'][i] == 'FuseA':
        test_df['Electrical'][i] = 80
    elif test_df['Electrical'][i] == 'FuseF':
        test_df['Electrical'][i] = 60
    elif test_df['Electrical'][i] == 'FuseP':
        test_df['Electrical'][i] = 40
    elif test_df['Electrical'][i] == 'Mix':
        test_df['Electrical'][i] = 20

for i in range(1460):
    if train_df['Functional'][i] == 'Typ':
        train_df['Functional'][i] = 100
    elif train_df['Functional'][i] == 'Min1':
        train_df['Functional'][i] = 80
    elif train_df['Functional'][i] == 'Min2':
        train_df['Functional'][i] = 60
    elif train_df['Functional'][i] == 'Mod':
        train_df['Functional'][i] = 40
    elif train_df['Functional'][i] == 'Maj1':
        train_df['Functional'][i] = 20
    elif train_df['Functional'][i] == 'Maj2':
        train_df['Functional'][i] = 10
    elif train_df['Functional'][i] == 'Sev' or train_df['Functional'][i] == 'Sal':
        train_df['Functional'][i] = 0

# Replace values in 'Functional' column for the test set
for i in range(1459):
    if test_df['Functional'][i] == 'Typ':
        test_df['Functional'][i] = 100
    elif test_df['Functional'][i] == 'Min1':
        test_df['Functional'][i] = 80
    elif test_df['Functional'][i] == 'Min2':
        test_df['Functional'][i] = 60
    elif test_df['Functional'][i] == 'Mod':
        test_df['Functional'][i] = 40
    elif test_df['Functional'][i] == 'Maj1':
        test_df['Functional'][i] = 20
    elif test_df['Functional'][i] == 'Maj2':
        test_df['Functional'][i] = 10
    elif test_df['Functional'][i] == 'Sev' or test_df['Functional'][i] == 'Sal':
        test_df['Functional'][i] = 0

for i in range(1460):
    if train_df['GarageType'][i] == 'Attchd':
        train_df['GarageType'][i] = 100
    elif train_df['GarageType'][i] == 'Detchd':
        train_df['GarageType'][i] = 80
    elif train_df['GarageType'][i] == 'BuiltIn':
        train_df['GarageType'][i] = 60
    elif train_df['GarageType'][i] == 'Basment' or train_df['GarageType'][i] == '2Types':
        train_df['GarageType'][i] = 40
    elif pd.isnull(train_df['GarageType'][i]):
        train_df['GarageType'][i] = 0
    else:
        train_df['GarageType'][i] = 20  # Handling other cases with a generic value

# Replace values in 'GarageType' column for the test set
for i in range(1459):
    if test_df['GarageType'][i] == 'Attchd':
        test_df['GarageType'][i] = 100
    elif test_df['GarageType'][i] == 'Detchd':
        test_df['GarageType'][i] = 80
    elif test_df['GarageType'][i] == 'BuiltIn':
        test_df['GarageType'][i] = 60
    elif test_df['GarageType'][i] == 'Basment' or test_df['GarageType'][i] == '2Types':
        test_df['GarageType'][i] = 40
    elif pd.isnull(test_df['GarageType'][i]):
        test_df['GarageType'][i] = 0
    else:
        test_df['GarageType'][i] = 20  # Handling other cases with a generic value

for i in range(1460):
    if train_df['MiscFeature'][i] == 'Elev':
        train_df['MiscFeature'][i] = 100
    elif train_df['MiscFeature'][i] == 'Gar2':
        train_df['MiscFeature'][i] = 80
    elif train_df['MiscFeature'][i] == 'Othr' or train_df['MiscFeature'][i] == 'TenC':
        train_df['MiscFeature'][i] = 60
    elif pd.isnull(train_df['MiscFeature'][i]):
        train_df['MiscFeature'][i] = 0
    else:
        train_df['MiscFeature'][i] = 40  # Handling other cases with a generic value

# Replace values in 'MiscFeature' column for the test set
for i in range(1459):
    if test_df['MiscFeature'][i] == 'Elev':
        test_df['MiscFeature'][i] = 100
    elif test_df['MiscFeature'][i] == 'Gar2':
        test_df['MiscFeature'][i] = 80
    elif test_df['MiscFeature'][i] == 'Othr' or test_df['MiscFeature'][i] == 'TenC':
        test_df['MiscFeature'][i] = 60
    elif pd.isnull(test_df['MiscFeature'][i]):
        test_df['MiscFeature'][i] = 0
    else:
        test_df['MiscFeature'][i] = 40

for i in range(1460):
    if train_df['SaleType'][i] == 'New':
        train_df['SaleType'][i] = 100
    elif train_df['SaleType'][i] == 'Con':
        train_df['SaleType'][i] = 80
    elif train_df['SaleType'][i] == 'CWD':
        train_df['SaleType'][i] = 60
    elif train_df['SaleType'][i] == 'ConLI' or train_df['SaleType'][i] == 'ConLw':
        train_df['SaleType'][i] = 40
    elif pd.isnull(train_df['SaleType'][i]):
        train_df['SaleType'][i] = 0
    else:
        train_df['SaleType'][i] = 20  # Handling other cases with a generic value

# Replace values in 'SaleType' column for the test set
for i in range(1459):
    if test_df['SaleType'][i] == 'New':
        test_df['SaleType'][i] = 100
    elif test_df['SaleType'][i] == 'Con':
        test_df['SaleType'][i] = 80
    elif test_df['SaleType'][i] == 'CWD':
        test_df['SaleType'][i] = 60
    elif test_df['SaleType'][i] == 'ConLI' or test_df['SaleType'][i] == 'ConLw':
        test_df['SaleType'][i] = 40
    elif pd.isnull(test_df['SaleType'][i]):
        test_df['SaleType'][i] = 0
    else:
        test_df['SaleType'][i] = 20

for i in range(1460):
    if train_df['RoofStyle'][i] == 'Shed':
        train_df['RoofStyle'][i] = 100
    elif train_df['RoofStyle'][i] == 'Hip':
        train_df['RoofStyle'][i] = 80
    elif train_df['RoofStyle'][i] == 'Gable':
        train_df['RoofStyle'][i] = 60
    elif train_df['RoofStyle'][i] == 'Flat' or train_df['RoofStyle'][i] == 'Gambrel' or train_df['RoofStyle'][i] == 'Mansard':
        train_df['RoofStyle'][i] = 40
    elif pd.isnull(train_df['RoofStyle'][i]):
        train_df['RoofStyle'][i] = 0
    else:
        train_df['RoofStyle'][i] = 20  # Handling other cases with a generic value

# Replace values in 'RoofStyle' column for the test set
for i in range(1459):
    if test_df['RoofStyle'][i] == 'Shed':
        test_df['RoofStyle'][i] = 100
    elif test_df['RoofStyle'][i] == 'Hip':
        test_df['RoofStyle'][i] = 80
    elif test_df['RoofStyle'][i] == 'Gable':
        test_df['RoofStyle'][i] = 60
    elif test_df['RoofStyle'][i] == 'Flat' or test_df['RoofStyle'][i] == 'Gambrel' or test_df['RoofStyle'][i] == 'Mansard':
        test_df['RoofStyle'][i] = 40
    elif pd.isnull(test_df['RoofStyle'][i]):
        test_df['RoofStyle'][i] = 0
    else:
        test_df['RoofStyle'][i] = 20

for i in range(1460):
    if train_df['RoofMatl'][i] == 'WdShngl':
        train_df['RoofMatl'][i] = 100
    elif train_df['RoofMatl'][i] == 'Metal' or train_df['RoofMatl'][i] == 'Roll':
        train_df['RoofMatl'][i] = 80
    elif train_df['RoofMatl'][i] == 'Membran':
        train_df['RoofMatl'][i] = 60
    elif train_df['RoofMatl'][i] == 'WdShake' or train_df['RoofMatl'][i] == 'ClyTile':
        train_df['RoofMatl'][i] = 40
    elif pd.isnull(train_df['RoofMatl'][i]):
        train_df['RoofMatl'][i] = 0
    else:
        train_df['RoofMatl'][i] = 20  # Handling other cases with a generic value

# Replace values in 'RoofMatl' column for the test set
for i in range(1459):
    if test_df['RoofMatl'][i] == 'WdShngl':
        test_df['RoofMatl'][i] = 100
    elif test_df['RoofMatl'][i] == 'Metal' or test_df['RoofMatl'][i] == 'Roll':
        test_df['RoofMatl'][i] = 80
    elif test_df['RoofMatl'][i] == 'Membran':
        test_df['RoofMatl'][i] = 60
    elif test_df['RoofMatl'][i] == 'WdShake' or test_df['RoofMatl'][i] == 'ClyTile':
        test_df['RoofMatl'][i] = 40
    elif pd.isnull(test_df['RoofMatl'][i]):
        test_df['RoofMatl'][i] = 0
    else:
        test_df['RoofMatl'][i] = 20


for i in range(1460):
    if train_df['Foundation'][i] == 'PConc':
        train_df['Foundation'][i] = 100
    elif train_df['Foundation'][i] == 'Wood':
        train_df['Foundation'][i] = 80
    elif train_df['Foundation'][i] == 'CBlock':
        train_df['Foundation'][i] = 60
    elif train_df['Foundation'][i] == 'Stone':
        train_df['Foundation'][i] = 40
    elif pd.isnull(train_df['Foundation'][i]):
        train_df['Foundation'][i] = 0
    else:
        train_df['Foundation'][i] = 20  # Handling other cases with a generic value

# Replace values in 'Foundation' column for the test set
for i in range(1459):
    if test_df['Foundation'][i] == 'PConc':
        test_df['Foundation'][i] = 100
    elif test_df['Foundation'][i] == 'Wood':
        test_df['Foundation'][i] = 80
    elif test_df['Foundation'][i] == 'CBlock':
        test_df['Foundation'][i] = 60
    elif test_df['Foundation'][i] == 'Stone':
        test_df['Foundation'][i] = 40
    elif pd.isnull(test_df['Foundation'][i]):
        test_df['Foundation'][i] = 0
    else:
        test_df['Foundation'][i] = 20

for i in range(1460):
    if train_df['MasVnrType'][i] == 'Stone':
        train_df['MasVnrType'][i] = 100
    elif train_df['MasVnrType'][i] == 'BrkFace':
        train_df['MasVnrType'][i] = 80
    elif train_df['MasVnrType'][i] == 'BrkCmn':
        train_df['MasVnrType'][i] = 60
    elif train_df['MasVnrType'][i] == 'None':
        train_df['MasVnrType'][i] = 40
    elif pd.isnull(train_df['MasVnrType'][i]):
        train_df['MasVnrType'][i] = 0
    else:
        train_df['MasVnrType'][i] = 20  # Handling other cases with a generic value

# Replace values in 'MasVnrType' column for the test set
for i in range(1459):
    if test_df['MasVnrType'][i] == 'Stone':
        test_df['MasVnrType'][i] = 100
    elif test_df['MasVnrType'][i] == 'BrkFace':
        test_df['MasVnrType'][i] = 80
    elif test_df['MasVnrType'][i] == 'BrkCmn':
        test_df['MasVnrType'][i] = 60
    elif test_df['MasVnrType'][i] == 'None':
        test_df['MasVnrType'][i] = 40
    elif pd.isnull(test_df['MasVnrType'][i]):
        test_df['MasVnrType'][i] = 0
    else:
        test_df['MasVnrType'][i] = 20

for i in range(1460):
    if train_df['HouseStyle'][i] == '2Story':
        train_df['HouseStyle'][i] = 100
    elif train_df['HouseStyle'][i] == '1Story':
        train_df['HouseStyle'][i] = 80
    elif train_df['HouseStyle'][i] == '1.5Fin' or train_df['HouseStyle'][i] == '1.5Unf':
        train_df['HouseStyle'][i] = 60
    elif train_df['HouseStyle'][i] == 'SFoyer':
        train_df['HouseStyle'][i] = 40
    elif train_df['HouseStyle'][i] == 'SLvl':
        train_df['HouseStyle'][i] = 20
    elif pd.isnull(train_df['HouseStyle'][i]):
        train_df['HouseStyle'][i] = 0
    else:
        train_df['HouseStyle'][i] = 10  # Handling other cases with a generic value

# Replace values in 'HouseStyle' column for the test set
for i in range(1459):
    if test_df['HouseStyle'][i] == '2Story':
        test_df['HouseStyle'][i] = 100
    elif test_df['HouseStyle'][i] == '1Story':
        test_df['HouseStyle'][i] = 80
    elif test_df['HouseStyle'][i] == '1.5Fin' or test_df['HouseStyle'][i] == '1.5Unf':
        test_df['HouseStyle'][i] = 60
    elif test_df['HouseStyle'][i] == 'SFoyer':
        test_df['HouseStyle'][i] = 40
    elif test_df['HouseStyle'][i] == 'SLvl':
        test_df['HouseStyle'][i] = 20
    elif pd.isnull(test_df['HouseStyle'][i]):
        test_df['HouseStyle'][i] = 0
    else:
        test_df['HouseStyle'][i] = 10

for i in range(1460):
    if train_df['BldgType'][i] == '1Fam':
        train_df['BldgType'][i] = 100
    elif train_df['BldgType'][i] == '2fmCon':
        train_df['BldgType'][i] = 80
    elif train_df['BldgType'][i] == 'Duplex':
        train_df['BldgType'][i] = 60
    elif train_df['BldgType'][i] == 'TwnhsE':
        train_df['BldgType'][i] = 40
    elif train_df['BldgType'][i] == 'Twnhs':
        train_df['BldgType'][i] = 20
    elif pd.isnull(train_df['BldgType'][i]):
        train_df['BldgType'][i] = 0
    else:
        train_df['BldgType'][i] = 10  # Handling other cases with a generic value

# Replace values in 'BldgType' column for the test set
for i in range(1459):
    if test_df['BldgType'][i] == '1Fam':
        test_df['BldgType'][i] = 100
    elif test_df['BldgType'][i] == '2fmCon':
        test_df['BldgType'][i] = 80
    elif test_df['BldgType'][i] == 'Duplex':
        test_df['BldgType'][i] = 60
    elif test_df['BldgType'][i] == 'TwnhsE':
        test_df['BldgType'][i] = 40
    elif test_df['BldgType'][i] == 'Twnhs':
        test_df['BldgType'][i] = 20
    elif pd.isnull(test_df['BldgType'][i]):
        test_df['BldgType'][i] = 0
    else:
        test_df['BldgType'][i] = 10

for i in range(1460):
    if train_df['Condition1'][i] == 'Norm':
        train_df['Condition1'][i] = 100
    elif train_df['Condition1'][i] == 'Feedr':
        train_df['Condition1'][i] = 80
    elif train_df['Condition1'][i] == 'Artery' or train_df['Condition1'][i] == 'RRAn':
        train_df['Condition1'][i] = 60
    elif train_df['Condition1'][i] == 'PosN':
        train_df['Condition1'][i] = 40
    elif train_df['Condition1'][i] == 'PosA':
        train_df['Condition1'][i] = 20
    elif pd.isnull(train_df['Condition1'][i]):
        train_df['Condition1'][i] = 0
    else:
        train_df['Condition1'][i] = 10  # Handling other cases with a generic value

# Replace values in 'Condition1' column for the test set
for i in range(1459):
    if test_df['Condition1'][i] == 'Norm':
        test_df['Condition1'][i] = 100
    elif test_df['Condition1'][i] == 'Feedr':
        test_df['Condition1'][i] = 80
    elif test_df['Condition1'][i] == 'Artery' or test_df['Condition1'][i] == 'RRAn':
        test_df['Condition1'][i] = 60
    elif test_df['Condition1'][i] == 'PosN':
        test_df['Condition1'][i] = 40
    elif test_df['Condition1'][i] == 'PosA':
        test_df['Condition1'][i] = 20
    elif pd.isnull(test_df['Condition1'][i]):
        test_df['Condition1'][i] = 0
    else:
        test_df['Condition1'][i] = 10

for i in range(1460):
    if train_df['Condition2'][i] == 'Norm':
        train_df['Condition2'][i] = 100
    elif train_df['Condition2'][i] == 'Feedr':
        train_df['Condition2'][i] = 80
    elif train_df['Condition2'][i] == 'Artery' or train_df['Condition2'][i] == 'RRAn':
        train_df['Condition2'][i] = 60
    elif train_df['Condition2'][i] == 'PosN':
        train_df['Condition2'][i] = 40
    elif train_df['Condition2'][i] == 'PosA':
        train_df['Condition2'][i] = 20
    elif pd.isnull(train_df['Condition2'][i]):
        train_df['Condition2'][i] = 0
    else:
        train_df['Condition2'][i] = 10  # Handling other cases with a generic value

# Replace values in 'Condition2' column for the test set
for i in range(1459):
    if test_df['Condition2'][i] == 'Norm':
        test_df['Condition2'][i] = 100
    elif test_df['Condition2'][i] == 'Feedr':
        test_df['Condition2'][i] = 80
    elif test_df['Condition2'][i] == 'Artery' or test_df['Condition2'][i] == 'RRAn':
        test_df['Condition2'][i] = 60
    elif test_df['Condition2'][i] == 'PosN':
        test_df['Condition2'][i] = 40
    elif test_df['Condition2'][i] == 'PosA':
        test_df['Condition2'][i] = 20
    elif pd.isnull(test_df['Condition2'][i]):
        test_df['Condition2'][i] = 0
    else:
        test_df['Condition2'][i] = 10

for i in range(1460):
    if train_df['Exterior1st'][i] == 'VinylSd':
        train_df['Exterior1st'][i] = 100
    elif train_df['Exterior1st'][i] == 'HdBoard':
        train_df['Exterior1st'][i] = 80
    elif train_df['Exterior1st'][i] == 'MetalSd' or train_df['Exterior1st'][i] == 'Wd Sdng':
        train_df['Exterior1st'][i] = 60
    elif train_df['Exterior1st'][i] == 'Plywood':
        train_df['Exterior1st'][i] = 40
    elif train_df['Exterior1st'][i] == 'CemntBd':
        train_df['Exterior1st'][i] = 20
    elif pd.isnull(train_df['Exterior1st'][i]):
        train_df['Exterior1st'][i] = 0
    else:
        train_df['Exterior1st'][i] = 10  # Handling other cases with a generic value

# Replace values in 'Exterior1st' column for the test set
for i in range(1459):
    if test_df['Exterior1st'][i] == 'VinylSd':
        test_df['Exterior1st'][i] = 100
    elif test_df['Exterior1st'][i] == 'HdBoard':
        test_df['Exterior1st'][i] = 80
    elif test_df['Exterior1st'][i] == 'MetalSd' or test_df['Exterior1st'][i] == 'Wd Sdng':
        test_df['Exterior1st'][i] = 60
    elif test_df['Exterior1st'][i] == 'Plywood':
        test_df['Exterior1st'][i] = 40
    elif test_df['Exterior1st'][i] == 'CemntBd':
        test_df['Exterior1st'][i] = 20
    elif pd.isnull(test_df['Exterior1st'][i]):
        test_df['Exterior1st'][i] = 0
    else:
        test_df['Exterior1st'][i] = 10

for i in range(1460):
    if train_df['Exterior2nd'][i] == 'VinylSd':
        train_df['Exterior2nd'][i] = 100
    elif train_df['Exterior2nd'][i] == 'HdBoard':
        train_df['Exterior2nd'][i] = 80
    elif train_df['Exterior2nd'][i] == 'MetalSd' or train_df['Exterior2nd'][i] == 'Wd Sdng':
        train_df['Exterior2nd'][i] = 60
    elif train_df['Exterior2nd'][i] == 'Plywood':
        train_df['Exterior2nd'][i] = 40
    elif train_df['Exterior2nd'][i] == 'CmentBd':
        train_df['Exterior2nd'][i] = 20
    elif pd.isnull(train_df['Exterior2nd'][i]):
        train_df['Exterior2nd'][i] = 0
    else:
        train_df['Exterior2nd'][i] = 10  # Handling other cases with a generic value

# Replace values in 'Exterior2nd' column for the test set
for i in range(1459):
    if test_df['Exterior2nd'][i] == 'VinylSd':
        test_df['Exterior2nd'][i] = 100
    elif test_df['Exterior2nd'][i] == 'HdBoard':
        test_df['Exterior2nd'][i] = 80
    elif test_df['Exterior2nd'][i] == 'MetalSd' or test_df['Exterior2nd'][i] == 'Wd Sdng':
        test_df['Exterior2nd'][i] = 60
    elif test_df['Exterior2nd'][i] == 'Plywood':
        test_df['Exterior2nd'][i] = 40
    elif test_df['Exterior2nd'][i] == 'CmentBd':
        test_df['Exterior2nd'][i] = 20
    elif pd.isnull(test_df['Exterior2nd'][i]):
        test_df['Exterior2nd'][i] = 0
    else:
        test_df['Exterior2nd'][i] = 10

for i in range(1460):
    if train_df['Neighborhood'][i] == 'NridgHt':
        train_df['Neighborhood'][i] = 100
    elif train_df['Neighborhood'][i] == 'NoRidge':
        train_df['Neighborhood'][i] = 80
    elif train_df['Neighborhood'][i] == 'StoneBr':
        train_df['Neighborhood'][i] = 60
    elif train_df['Neighborhood'][i] == 'Timber':
        train_df['Neighborhood'][i] = 40
    elif train_df['Neighborhood'][i] == 'Somerst':
        train_df['Neighborhood'][i] = 20
    elif pd.isnull(train_df['Neighborhood'][i]):
        train_df['Neighborhood'][i] = 0
    else:
        train_df['Neighborhood'][i] = 10  # Handling other cases with a generic value

# Replace values in 'Neighborhood' column for the test set
for i in range(1459):
    if test_df['Neighborhood'][i] == 'NridgHt':
        test_df['Neighborhood'][i] = 100
    elif test_df['Neighborhood'][i] == 'NoRidge':
        test_df['Neighborhood'][i] = 80
    elif test_df['Neighborhood'][i] == 'StoneBr':
        test_df['Neighborhood'][i] = 60
    elif test_df['Neighborhood'][i] == 'Timber':
        test_df['Neighborhood'][i] = 40
    elif test_df['Neighborhood'][i] == 'Somerst':
        test_df['Neighborhood'][i] = 20
    elif pd.isnull(test_df['Neighborhood'][i]):
        test_df['Neighborhood'][i] = 0
    else:
        test_df['Neighborhood'][i] = 10


for i in range (0,1460):
  if train_df['MSZoning'][i]=='A':
    train_df['MSZoning'][i]=10
  elif train_df['MSZoning'][i]=='C':
    train_df['MSZoning'][i]=30
  elif train_df['MSZoning'][i]=='FV':
    train_df['MSZoning'][i]=50
  elif train_df['MSZoning'][i]=='I':
    train_df['MSZoning'][i]=0
  elif train_df['MSZoning'][i]=='RH':
    train_df['MSZoning'][i]=100
  elif train_df['MSZoning'][i]=='RL':
    train_df['MSZoning'][i]=60
  elif train_df['MSZoning'][i]=='RP':
    train_df['MSZoning'][i]=70
  elif train_df['MSZoning'][i]=='RM':
    train_df['MSZoning'][i]=80
  if train_df['Street'][i]=='Grvl':
    train_df['Street'][i]=0
  elif train_df['Street'][i]=='Pave':
    train_df['Street'][i]=1
  if train_df['Alley'][i]=='Pave':
    train_df['Alley'][i]=5
  elif train_df['Alley'][i]=='Grvl':
    train_df['Alley'][i]=5
  elif train_df['Alley'][i]=='NaN':
    train_df['Alley'][i]=0
  if train_df['LotShape'][i]=='Reg':
    train_df['LotShape'][i]=100
  elif train_df['LotShape'][i]=='IR1' :
    train_df['LotShape'][i]=80
  elif train_df['LotShape'][i]=='IR2':
    train_df['LotShape'][i]=50
  elif train_df['LotShape'][i]=='IR3' :
    train_df['LotShape'][i]=0
  if train_df['LandContour'][i]=='Lvl':
    train_df['LandContour'][i]=100
  elif train_df['LandContour'][i]=='Bnk':
    train_df['LandContour'][i]=60
  elif train_df['LandContour'][i]=='HLS':
    train_df['LandContour'][i]=30
  elif train_df['LandContour'][i]=='Low':
    train_df['LandContour'][i]=0
  if train_df['Utilities'][i]=='AllPub':
    train_df['LandContour'][i]=100
  elif train_df['LandContour'][i]=='NoSewr':
    train_df['LandContour'][i]=80
  elif train_df['LandContour'][i]=='NoSeWa':
    train_df['LandContour'][i]=50
  elif train_df['LandContour'][i]=='ELO':
    train_df['LandContour'][i]=30
  if train_df['LotConfig'][i]=='Inside':
    train_df['LotConfig'][i]=100
  elif train_df['LotConfig'][i]=='Corner':
    train_df['LotConfig'][i]=80
  elif train_df['LotConfig'][i]=='CulDSac':
    train_df['LotConfig'][i]=60
  elif train_df['LotConfig'][i]=='FR2':
    train_df['LotConfig'][i]=40
  elif train_df['LotConfig'][i]=='FR3':
    train_df['LotConfig'][i]=20
  if train_df['LandSlope'][i]=='Gtl':
    train_df['LandSlope'][i]=100
  elif train_df['LandSlope'][i]=='Mod':
    train_df['LandSlope'][i]=50
  elif train_df['LandSlope'][i]=='Sev':
    train_df['LandSlope'][i]=0
  if train_df['Foundation'][i]=='BrkTil':
    train_df['Foundation'][i]=100
  elif train_df['Foundation'][i]=='CBlock':
    train_df['Foundation'][i]=80
  elif train_df['Foundation'][i]=='PConc':
    train_df['Foundation'][i]=70
  elif train_df['Foundation'][i]=='Slab':
    train_df['Foundation'][i]=60
  elif train_df['Foundation'][i]=='Stone':
    train_df['Foundation'][i]=40
  elif train_df['Foundation'][i]=='Wood':
    train_df['Foundation'][i]=0
  if train_df['MasVnrType'][i]=='BrkCmn':
    train_df['MasVnrType'][i]=100
  elif train_df['MasVnrType'][i]=='BrkFace':
    train_df['MasVnrType'][i]=80
  elif train_df['MasVnrType'][i]=='CBlock':
    train_df['MasVnrType'][i]=60
  elif train_df['MasVnrType'][i]=='Stone':
    train_df['MasVnrType'][i]=40
  elif train_df['MasVnrType'][i]=='None':
    train_df['MasVnrType'][i]=0
  if(train_df['SaleCondition'][i]=="Abnorml"):
    train_df['SaleCondition'][i]=100;
  elif(train_df['SaleCondition'][i]=='Normal'):
    train_df['SaleCondition'][i]=50;
  elif(train_df['SaleCondition'][i]=='AdjLand'):
    train_df['SaleCondition'][i]=70
  elif(train_df['SaleCondition'][i]=='Alloca'):
    train_df['SaleCondition'][i]=60
  elif(train_df['SaleCondition'][i]=='Family'):
    train_df['SaleCondition'][i]=80
  elif(train_df['SaleCondition'][i]=='Partial'):
    train_df['SaleCondition'][i]=0
  if(train_df['Fence'][i]=='GdPrv'):
    train_df['Fence'][i]=100
  elif(train_df['Fence'][i]=='MnPrv'):
    train_df['Fence'][i]=30
  elif(train_df['Fence'][i]=='GdWo'):
    train_df['Fence'][i]=80
  elif(train_df['Fence'][i]=='MnWw'):
    train_df['Fence'][i]=50
  elif(train_df['Fence'][i]=='NaN'):
    train_df['Fence'][i]=0
  if(train_df['PoolQC'][i]=='Ex'):
    train_df['PoolQC'][i]=100
  elif(train_df['PoolQC'][i]=='Gd'):
    train_df['PoolQC'][i]=80
  elif(train_df['PoolQC'][i]=='TA'):
    train_df['PoolQC'][i]=60
  elif(train_df['PoolQC'][i]=='Fa'):
    train_df['PoolQC'][i]=40
  elif(train_df['PoolQC'][i]=='NaN'):
    train_df['PoolQC'][i]=0
  if(train_df['PavedDrive'][i]=='Ex'):
    train_df['PavedDrive'][i]=100
  elif(train_df['PavedDrive'][i]=='Gd'):
    train_df['PavedDrive'][i]=50
  elif(train_df['PavedDrive'][i]=='TA'):
    train_df['PavedDrive'][i]=0
  if(train_df['GarageCond'][i]=='Ex'):
    train_df['GarageCond'][i]=100
  elif(train_df['GarageCond'][i]=='Gd'):
    train_df['GarageCond'][i]=80
  elif(train_df['GarageCond'][i]=='TA'):
    train_df['GarageCond'][i]=60
  elif(train_df['GarageCond'][i]=='Fa'):
    train_df['GarageCond'][i]=40
  elif(train_df['GarageCond'][i]=='NaN'):
    train_df['GarageCond'][i]=0
  elif(train_df['GarageCond'][i]=='Po'):
    train_df['GarageCond'][i]=20
  if(train_df['GarageQual'][i]=='Ex'):
    train_df['GarageQual'][i]=100
  elif(train_df['GarageQual'][i]=='Gd'):
    train_df['GarageQual'][i]=80
  elif(train_df['GarageQual'][i]=='TA'):
    train_df['GarageQual'][i]=60
  elif(train_df['GarageQual'][i]=='Fa'):
    train_df['GarageQual'][i]=40
  elif(train_df['GarageQual'][i]=='NaN'):
    train_df['GarageQual'][i]=0
  elif(train_df['GarageQual'][i]=='Po'):
    train_df['GarageQual'][i]=20




for i in range (0,1459):
    if test_df['MSZoning'][i]=='A' :
      test_df['MSZoning'][i]=10
    elif test_df['MSZoning'][i]=='C':
      test_df['MSZoning'][i]=30
    elif test_df['MSZoning'][i]=='FV':
      test_df['MSZoning'][i]=50
    elif test_df['MSZoning'][i]=='I':
      test_df['MSZoning'][i]=0
    elif test_df['MSZoning'][i]=='RH':
      test_df['MSZoning'][i]=100
    elif test_df['MSZoning'][i]=='RL':
      test_df['MSZoning'][i]=60
    elif test_df['MSZoning'][i]=='RP':
      test_df['MSZoning'][i]=70
    elif test_df['MSZoning'][i]=='RM':
      test_df['MSZoning'][i]=80
    if test_df['Street'][i]=='Grvl':
      test_df['Street'][i]=0
    elif test_df['Street'][i]=='Pave':
      test_df['Street'][i]=1
    if test_df['Alley'][i]=='Pave':
      test_df['Alley'][i]=5
    elif test_df['Alley'][i]=='Grvl':
      test_df['Alley'][i]=5
    elif test_df['Alley'][i]=='NaN':
      test_df['Alley'][i]=0
    if test_df['LotShape'][i]=='Reg':
      test_df['LotShape'][i]=100
    elif test_df['LotShape'][i]=='IR1' :
      test_df['LotShape'][i]=80
    elif test_df['LotShape'][i]=='IR2':
      test_df['LotShape'][i]=50
    elif test_df['LotShape'][i]=='IR3' :
      test_df['LotShape'][i]=0
    if test_df['LandContour'][i]=='Lvl':
      test_df['LandContour'][i]=100
    elif test_df['LandContour'][i]=='Bnk':
      test_df['LandContour'][i]=60
    elif test_df['LandContour'][i]=='HLS':
      test_df['LandContour'][i]=30
    elif test_df['LandContour'][i]=='Low':
      test_df['LandContour'][i]=0
    if test_df['Utilities'][i]=='AllPub':
      test_df['LandContour'][i]=100
    elif test_df['LandContour'][i]=='NoSewr':
      test_df['LandContour'][i]=80
    elif test_df['LandContour'][i]=='NoSeWa':
      test_df['LandContour'][i]=50
    elif test_df['LandContour'][i]=='ELO':
      test_df['LandContour'][i]=30
    if test_df['LotConfig'][i]=='Inside':
      test_df['LotConfig'][i]=100
    elif test_df['LotConfig'][i]=='Corner':
      test_df['LotConfig'][i]=80
    elif test_df['LotConfig'][i]=='CulDSac':
      test_df['LotConfig'][i]=60
    elif test_df['LotConfig'][i]=='FR2':
      test_df['LotConfig'][i]=40
    elif test_df['LotConfig'][i]=='FR3':
      test_df['LotConfig'][i]=20
    if test_df['LandSlope'][i]=='Gtl':
      test_df['LandSlope'][i]=100
    elif test_df['LandSlope'][i]=='Mod':
      test_df['LandSlope'][i]=50
    elif test_df['LandSlope'][i]=='Sev':
      test_df['LandSlope'][i]=0
    if test_df['Foundation'][i]=='BrkTil':
      test_df['Foundation'][i]=100
    elif test_df['Foundation'][i]=='CBlock':
      test_df['Foundation'][i]=80
    elif test_df['Foundation'][i]=='PConc':
      test_df['Foundation'][i]=70
    elif test_df['Foundation'][i]=='Slab':
      test_df['Foundation'][i]=60
    elif test_df['Foundation'][i]=='Stone':
      test_df['Foundation'][i]=40
    elif test_df['Foundation'][i]=='Wood':
      test_df['Foundation'][i]=0
    if test_df['MasVnrType'][i]=='BrkCmn':
      test_df['MasVnrType'][i]=100
    elif test_df['MasVnrType'][i]=='BrkFace':
      test_df['MasVnrType'][i]=80
    elif test_df['MasVnrType'][i]=='CBlock':
      test_df['MasVnrType'][i]=60
    elif test_df['MasVnrType'][i]=='Stone':
      test_df['MasVnrType'][i]=40
    elif test_df['MasVnrType'][i]=='None':
      test_df['MasVnrType'][i]=0
    if(test_df['SaleCondition'][i]=="Abnorml"):
      test_df['SaleCondition'][i]=100;
    elif(test_df['SaleCondition'][i]=='Normal'):
      test_df['SaleCondition'][i]=50;
    elif(test_df['SaleCondition'][i]=='AdjLand'):
      test_df['SaleCondition'][i]=70
    elif(test_df['SaleCondition'][i]=='Alloca'):
      test_df['SaleCondition'][i]=60
    elif(test_df['SaleCondition'][i]=='Family'):
      test_df['SaleCondition'][i]=80
    elif(test_df['SaleCondition'][i]=='Partial'):
      test_df['SaleCondition'][i]=0
    if(test_df['Fence'][i]=='GdPrv'):
      test_df['Fence'][i]=100
    elif(test_df['Fence'][i]=='MnPrv'):
      test_df['Fence'][i]=30
    elif(test_df['Fence'][i]=='GdWo'):
      test_df['Fence'][i]=80
    elif(test_df['Fence'][i]=='MnWw'):
      test_df['Fence'][i]=50
    elif(test_df['Fence'][i]=='NaN'):
      test_df['Fence'][i]=0
    if(test_df['PoolQC'][i]=='Ex'):
      test_df['PoolQC'][i]=100
    elif(test_df['PoolQC'][i]=='Gd'):
      test_df['PoolQC'][i]=80
    elif(test_df['PoolQC'][i]=='TA'):
      test_df['PoolQC'][i]=60
    elif(test_df['PoolQC'][i]=='Fa'):
      test_df['PoolQC'][i]=40
    elif(test_df['PoolQC'][i]=='NaN'):
      test_df['PoolQC'][i]=0
    if(test_df['PavedDrive'][i]=='Ex'):
      test_df['PavedDrive'][i]=100
    elif(test_df['PavedDrive'][i]=='Gd'):
      test_df['PavedDrive'][i]=50
    elif(test_df['PavedDrive'][i]=='TA'):
      test_df['PavedDrive'][i]=0
    if(test_df['GarageCond'][i]=='Ex'):
      test_df['GarageCond'][i]=100
    elif(test_df['GarageCond'][i]=='Gd'):
      test_df['GarageCond'][i]=80
    elif(test_df['GarageCond'][i]=='TA'):
      test_df['GarageCond'][i]=60
    elif(test_df['GarageCond'][i]=='Fa'):
      test_df['GarageCond'][i]=40
    elif(test_df['GarageCond'][i]=='NaN'):
      test_df['GarageCond'][i]=0
    elif(test_df['GarageCond'][i]=='Po'):
      test_df['GarageCond'][i]=20
    if(test_df['GarageQual'][i]=='Ex'):
      test_df['GarageQual'][i]=100
    elif(test_df['GarageQual'][i]=='Gd'):
      test_df['GarageQual'][i]=80
    elif(test_df['GarageQual'][i]=='TA'):
      test_df['GarageQual'][i]=60
    elif(test_df['GarageQual'][i]=='Fa'):
      test_df['GarageQual'][i]=40
    elif(test_df['GarageQual'][i]=='NaN'):
      test_df['GarageQual'][i]=0
    elif(test_df['GarageQual'][i]=='Po'):
      test_df['GarageQual'][i]=20
# Out:
# <ipython-input-60-e1892bad319e>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['FireplaceQu'][i]=60
# <ipython-input-60-e1892bad319e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['FireplaceQu'][i]=80
# <ipython-input-60-e1892bad319e>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['FireplaceQu'][i]=40
# <ipython-input-60-e1892bad319e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['FireplaceQu'][i]=100
# <ipython-input-60-e1892bad319e>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['FireplaceQu'][i]=20
# <ipython-input-60-e1892bad319e>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['FireplaceQu'][i]=60
# <ipython-input-60-e1892bad319e>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['FireplaceQu'][i]=80
# <ipython-input-60-e1892bad319e>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['FireplaceQu'][i]=20
# <ipython-input-60-e1892bad319e>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['FireplaceQu'][i]=40
# <ipython-input-60-e1892bad319e>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['FireplaceQu'][i]=100
# <ipython-input-60-e1892bad319e>:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['KitchenQual'][i]=80
# <ipython-input-60-e1892bad319e>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['KitchenQual'][i]=60
# <ipython-input-60-e1892bad319e>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['KitchenQual'][i]=100
# <ipython-input-60-e1892bad319e>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['KitchenQual'][i]=40
# <ipython-input-60-e1892bad319e>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['KitchenQual'][i]=60
# <ipython-input-60-e1892bad319e>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['KitchenQual'][i]=80
# <ipython-input-60-e1892bad319e>:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['KitchenQual'][i]=100
# <ipython-input-60-e1892bad319e>:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['KitchenQual'][i]=40
# <ipython-input-60-e1892bad319e>:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['HeatingQC'][i]=100
# <ipython-input-60-e1892bad319e>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['HeatingQC'][i]=80
# <ipython-input-60-e1892bad319e>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['HeatingQC'][i]=60
# <ipython-input-60-e1892bad319e>:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['HeatingQC'][i]=40
# <ipython-input-60-e1892bad319e>:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['HeatingQC'][i]=20
# <ipython-input-60-e1892bad319e>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['HeatingQC'][i]=60
# <ipython-input-60-e1892bad319e>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['HeatingQC'][i]=80
# <ipython-input-60-e1892bad319e>:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['HeatingQC'][i]=100
# <ipython-input-60-e1892bad319e>:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['HeatingQC'][i]=40
# <ipython-input-60-e1892bad319e>:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['HeatingQC'][i]=20
# <ipython-input-60-e1892bad319e>:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['CentralAir'][i]=100
# <ipython-input-60-e1892bad319e>:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['CentralAir'][i]=0
# <ipython-input-60-e1892bad319e>:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['CentralAir'][i]=100
# <ipython-input-60-e1892bad319e>:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['CentralAir'][i]=0
# <ipython-input-60-e1892bad319e>:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['GarageFinish'][i]=80
# <ipython-input-60-e1892bad319e>:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['GarageFinish'][i]=40
# <ipython-input-60-e1892bad319e>:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['GarageFinish'][i]=100
# <ipython-input-60-e1892bad319e>:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['GarageFinish'][i]=40
# <ipython-input-60-e1892bad319e>:108: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['GarageFinish'][i]=100
# <ipython-input-60-e1892bad319e>:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['GarageFinish'][i]=80
# <ipython-input-60-e1892bad319e>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['ExterQual'][i]=80
# <ipython-input-60-e1892bad319e>:123: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['ExterQual'][i]=60
# <ipython-input-60-e1892bad319e>:119: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['ExterQual'][i]=100
# <ipython-input-60-e1892bad319e>:125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['ExterQual'][i]=40
# <ipython-input-60-e1892bad319e>:136: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['ExterQual'][i]=60
# <ipython-input-60-e1892bad319e>:134: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['ExterQual'][i]=80
# <ipython-input-60-e1892bad319e>:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['ExterQual'][i]=100
# <ipython-input-60-e1892bad319e>:138: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['ExterQual'][i]=40
# <ipython-input-60-e1892bad319e>:149: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['ExterCond'][i]=60
# <ipython-input-60-e1892bad319e>:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['ExterCond'][i]=80
# <ipython-input-60-e1892bad319e>:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['ExterCond'][i]=40
# <ipython-input-60-e1892bad319e>:153: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['ExterCond'][i]=20
# <ipython-input-60-e1892bad319e>:145: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['ExterCond'][i]=100
# <ipython-input-60-e1892bad319e>:162: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['ExterCond'][i]=60
# <ipython-input-60-e1892bad319e>:160: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['ExterCond'][i]=80
# <ipython-input-60-e1892bad319e>:164: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['ExterCond'][i]=40
# <ipython-input-60-e1892bad319e>:166: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['ExterCond'][i]=20
# <ipython-input-60-e1892bad319e>:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['ExterCond'][i]=100
# <ipython-input-60-e1892bad319e>:173: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['BsmtQual'][i]=80
# <ipython-input-60-e1892bad319e>:175: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['BsmtQual'][i]=60
# <ipython-input-60-e1892bad319e>:171: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['BsmtQual'][i]=100
# <ipython-input-60-e1892bad319e>:177: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['BsmtQual'][i]=40
# <ipython-input-60-e1892bad319e>:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['BsmtQual'][i]=60
# <ipython-input-60-e1892bad319e>:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['BsmtQual'][i]=80
# <ipython-input-60-e1892bad319e>:186: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['BsmtQual'][i]=100
# <ipython-input-60-e1892bad319e>:192: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['BsmtQual'][i]=40
# <ipython-input-60-e1892bad319e>:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['BsmtExposure'][i] = 40
# <ipython-input-60-e1892bad319e>:201: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['BsmtExposure'][i] = 100
# <ipython-input-60-e1892bad319e>:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['BsmtExposure'][i] = 60
# <ipython-input-60-e1892bad319e>:203: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['BsmtExposure'][i] = 80
# <ipython-input-60-e1892bad319e>:209: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['BsmtExposure'][i] = 0
# <ipython-input-60-e1892bad319e>:220: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['BsmtExposure'][i] = 40
# <ipython-input-60-e1892bad319e>:214: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['BsmtExposure'][i] = 100
# <ipython-input-60-e1892bad319e>:218: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['BsmtExposure'][i] = 60
# <ipython-input-60-e1892bad319e>:216: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['BsmtExposure'][i] = 80
# <ipython-input-60-e1892bad319e>:222: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['BsmtExposure'][i] = 0
# <ipython-input-60-e1892bad319e>:227: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['BsmtFinType1'][i] = 100
# <ipython-input-60-e1892bad319e>:229: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['BsmtFinType1'][i] = 80
# <ipython-input-60-e1892bad319e>:233: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['BsmtFinType1'][i] = 40
# <ipython-input-60-e1892bad319e>:231: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['BsmtFinType1'][i] = 60
# <ipython-input-60-e1892bad319e>:237: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['BsmtFinType1'][i] = 0
# <ipython-input-60-e1892bad319e>:235: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['BsmtFinType1'][i] = 20
# <ipython-input-60-e1892bad319e>:248: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['BsmtFinType1'][i] = 40
# <ipython-input-60-e1892bad319e>:244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['BsmtFinType1'][i] = 80
# <ipython-input-60-e1892bad319e>:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['BsmtFinType1'][i] = 100
# <ipython-input-60-e1892bad319e>:246: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['BsmtFinType1'][i] = 60
# <ipython-input-60-e1892bad319e>:250: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['BsmtFinType1'][i] = 20
# <ipython-input-60-e1892bad319e>:252: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['BsmtFinType1'][i] = 0
# <ipython-input-60-e1892bad319e>:260: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['BsmtFinType2'][i] = 60
# <ipython-input-60-e1892bad319e>:266: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['BsmtFinType2'][i] = 0
# <ipython-input-60-e1892bad319e>:258: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['BsmtFinType2'][i] = 80
# <ipython-input-60-e1892bad319e>:262: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['BsmtFinType2'][i] = 40
# <ipython-input-60-e1892bad319e>:264: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['BsmtFinType2'][i] = 20
# <ipython-input-60-e1892bad319e>:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['BsmtFinType2'][i] = 100
# <ipython-input-60-e1892bad319e>:279: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['BsmtFinType2'][i] = 20
# <ipython-input-60-e1892bad319e>:277: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['BsmtFinType2'][i] = 40
# <ipython-input-60-e1892bad319e>:275: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['BsmtFinType2'][i] = 60
# <ipython-input-60-e1892bad319e>:271: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['BsmtFinType2'][i] = 100
# <ipython-input-60-e1892bad319e>:273: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['BsmtFinType2'][i] = 80
# <ipython-input-60-e1892bad319e>:281: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['BsmtFinType2'][i] = 0
# <ipython-input-60-e1892bad319e>:285: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['Heating'][i] = 100
# <ipython-input-60-e1892bad319e>:287: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['Heating'][i] = 80
# <ipython-input-60-e1892bad319e>:289: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['Heating'][i] = 60
# <ipython-input-60-e1892bad319e>:291: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['Heating'][i] = 40
# <ipython-input-60-e1892bad319e>:293: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['Heating'][i] = 20
# <ipython-input-60-e1892bad319e>:295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['Heating'][i] = 10
# <ipython-input-60-e1892bad319e>:300: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['Heating'][i] = 100
# <ipython-input-60-e1892bad319e>:302: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['Heating'][i] = 80
# <ipython-input-60-e1892bad319e>:304: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['Heating'][i] = 60
# <ipython-input-60-e1892bad319e>:306: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['Heating'][i] = 40
# <ipython-input-60-e1892bad319e>:314: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['Electrical'][i] = 100
# <ipython-input-60-e1892bad319e>:318: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['Electrical'][i] = 60
# <ipython-input-60-e1892bad319e>:316: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['Electrical'][i] = 80
# <ipython-input-60-e1892bad319e>:320: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['Electrical'][i] = 40
# <ipython-input-60-e1892bad319e>:322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['Electrical'][i] = 20
# <ipython-input-60-e1892bad319e>:327: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['Electrical'][i] = 100
# <ipython-input-60-e1892bad319e>:329: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['Electrical'][i] = 80
# <ipython-input-60-e1892bad319e>:331: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['Electrical'][i] = 60
# <ipython-input-60-e1892bad319e>:333: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['Electrical'][i] = 40
# <ipython-input-60-e1892bad319e>:339: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['Functional'][i] = 100
# <ipython-input-60-e1892bad319e>:341: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['Functional'][i] = 80
# <ipython-input-60-e1892bad319e>:347: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['Functional'][i] = 20
# <ipython-input-60-e1892bad319e>:343: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['Functional'][i] = 60
# <ipython-input-60-e1892bad319e>:345: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['Functional'][i] = 40
# <ipython-input-60-e1892bad319e>:349: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['Functional'][i] = 10
# <ipython-input-60-e1892bad319e>:351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['Functional'][i] = 0
# <ipython-input-60-e1892bad319e>:356: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['Functional'][i] = 100
# <ipython-input-60-e1892bad319e>:360: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['Functional'][i] = 60
# <ipython-input-60-e1892bad319e>:358: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['Functional'][i] = 80
# <ipython-input-60-e1892bad319e>:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['Functional'][i] = 40
# <ipython-input-60-e1892bad319e>:364: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['Functional'][i] = 20
# <ipython-input-60-e1892bad319e>:368: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['Functional'][i] = 0
# <ipython-input-60-e1892bad319e>:366: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['Functional'][i] = 10
# <ipython-input-60-e1892bad319e>:372: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['GarageType'][i] = 100
# <ipython-input-60-e1892bad319e>:374: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['GarageType'][i] = 80
# <ipython-input-60-e1892bad319e>:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['GarageType'][i] = 60
# <ipython-input-60-e1892bad319e>:382: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['GarageType'][i] = 20  # Handling other cases with a generic value
# <ipython-input-60-e1892bad319e>:380: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['GarageType'][i] = 0
# <ipython-input-60-e1892bad319e>:378: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['GarageType'][i] = 40
# <ipython-input-60-e1892bad319e>:387: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['GarageType'][i] = 100
# <ipython-input-60-e1892bad319e>:389: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['GarageType'][i] = 80
# <ipython-input-60-e1892bad319e>:391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['GarageType'][i] = 60
# <ipython-input-60-e1892bad319e>:395: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['GarageType'][i] = 0
# <ipython-input-60-e1892bad319e>:393: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['GarageType'][i] = 40
# <ipython-input-60-e1892bad319e>:397: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['GarageType'][i] = 20  # Handling other cases with a generic value
# <ipython-input-60-e1892bad319e>:407: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['MiscFeature'][i] = 0
# <ipython-input-60-e1892bad319e>:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['MiscFeature'][i] = 40  # Handling other cases with a generic value
# <ipython-input-60-e1892bad319e>:403: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['MiscFeature'][i] = 80
# <ipython-input-60-e1892bad319e>:405: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['MiscFeature'][i] = 60
# <ipython-input-60-e1892bad319e>:420: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['MiscFeature'][i] = 0
# <ipython-input-60-e1892bad319e>:416: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['MiscFeature'][i] = 80
# <ipython-input-60-e1892bad319e>:422: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['MiscFeature'][i] = 40
# <ipython-input-60-e1892bad319e>:418: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['MiscFeature'][i] = 60
# <ipython-input-60-e1892bad319e>:436: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['SaleType'][i] = 20  # Handling other cases with a generic value
# <ipython-input-60-e1892bad319e>:426: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['SaleType'][i] = 100
# <ipython-input-60-e1892bad319e>:432: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['SaleType'][i] = 40
# <ipython-input-60-e1892bad319e>:430: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['SaleType'][i] = 60
# <ipython-input-60-e1892bad319e>:428: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['SaleType'][i] = 80
# <ipython-input-60-e1892bad319e>:451: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['SaleType'][i] = 20
# <ipython-input-60-e1892bad319e>:441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['SaleType'][i] = 100
# <ipython-input-60-e1892bad319e>:443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['SaleType'][i] = 80
# <ipython-input-60-e1892bad319e>:447: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['GarageCond'][i]=20
# <ipython-input-60-e1892bad319e>:952: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['GarageQual'][i]=20
# <ipython-input-60-e1892bad319e>:836: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['LotShape'][i]=0
# <ipython-input-60-e1892bad319e>:930: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['GarageCond'][i]=100
# <ipython-input-60-e1892bad319e>:862: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['LotConfig'][i]=20
# <ipython-input-60-e1892bad319e>:812: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['MSZoning'][i]=100
# <ipython-input-60-e1892bad319e>:920: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['PoolQC'][i]=40
# <ipython-input-60-e1892bad319e>:916: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['PoolQC'][i]=80
# <ipython-input-60-e1892bad319e>:967: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['MSZoning'][i]=100
# <ipython-input-60-e1892bad319e>:977: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['Street'][i]=1
# <ipython-input-60-e1892bad319e>:985: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['LotShape'][i]=100
# <ipython-input-60-e1892bad319e>:993: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['LandContour'][i]=100
# <ipython-input-60-e1892bad319e>:1001: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['LandContour'][i]=100
# <ipython-input-60-e1892bad319e>:1009: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['LotConfig'][i]=100
# <ipython-input-60-e1892bad319e>:1019: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['LandSlope'][i]=100
# <ipython-input-60-e1892bad319e>:1049: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['SaleCondition'][i]=50;
# <ipython-input-60-e1892bad319e>:1061: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['Fence'][i]=30
# <ipython-input-60-e1892bad319e>:1089: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['GarageCond'][i]=60
# <ipython-input-60-e1892bad319e>:1101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['GarageQual'][i]=60
# <ipython-input-60-e1892bad319e>:969: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['MSZoning'][i]=60
# <ipython-input-60-e1892bad319e>:987: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['LotShape'][i]=80
# <ipython-input-60-e1892bad319e>:1011: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['LotConfig'][i]=80
# <ipython-input-60-e1892bad319e>:997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['LandContour'][i]=30
# <ipython-input-60-e1892bad319e>:1059: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['Fence'][i]=100
# <ipython-input-60-e1892bad319e>:1015: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['LotConfig'][i]=40
# <ipython-input-60-e1892bad319e>:973: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['MSZoning'][i]=80
# <ipython-input-60-e1892bad319e>:1057: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['SaleCondition'][i]=0
# <ipython-input-60-e1892bad319e>:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['LandSlope'][i]=50
# <ipython-input-60-e1892bad319e>:989: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['LotShape'][i]=50
# <ipython-input-60-e1892bad319e>:1013: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['LotConfig'][i]=60
# <ipython-input-60-e1892bad319e>:963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['MSZoning'][i]=50
# <ipython-input-60-e1892bad319e>:1047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['SaleCondition'][i]=100;
# <ipython-input-60-e1892bad319e>:979: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['Alley'][i]=5
# <ipython-input-60-e1892bad319e>:1063: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['Fence'][i]=80
# <ipython-input-60-e1892bad319e>:1055: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['SaleCondition'][i]=80
# <ipython-input-60-e1892bad319e>:981: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['Alley'][i]=5
# <ipython-input-60-e1892bad319e>:995: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['LandContour'][i]=60
# <ipython-input-60-e1892bad319e>:1103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['GarageQual'][i]=40
# <ipython-input-60-e1892bad319e>:1091: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['GarageCond'][i]=40
# <ipython-input-60-e1892bad319e>:999: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['LandContour'][i]=0
# <ipython-input-60-e1892bad319e>:1087: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['GarageCond'][i]=80
# <ipython-input-60-e1892bad319e>:1099: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['GarageQual'][i]=80
# <ipython-input-60-e1892bad319e>:975: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['Street'][i]=0
# <ipython-input-60-e1892bad319e>:1053: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['SaleCondition'][i]=60
# <ipython-input-60-e1892bad319e>:1017: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['LotConfig'][i]=20
# <ipython-input-60-e1892bad319e>:991: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['LotShape'][i]=0
# <ipython-input-60-e1892bad319e>:1095: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['GarageCond'][i]=20
# <ipython-input-60-e1892bad319e>:1107: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['GarageQual'][i]=20
# <ipython-input-60-e1892bad319e>:1069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['PoolQC'][i]=100
# <ipython-input-60-e1892bad319e>:1023: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['LandSlope'][i]=0
# <ipython-input-60-e1892bad319e>:1065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['Fence'][i]=50
# <ipython-input-60-e1892bad319e>:1051: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['SaleCondition'][i]=70
# <ipython-input-60-e1892bad319e>:1085: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['GarageCond'][i]=100
# <ipython-input-60-e1892bad319e>:1071: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['PoolQC'][i]=80

# %%
del train_df['Id']
del test_df['Id']

train_df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       60         65.0     8450      1   NaN      100
# 1          20       60         80.0     9600      1   NaN      100
# 2          60       60         68.0    11250      1   NaN       80
# 3          70       60         60.0     9550      1   NaN       80
# 4          60       60         84.0    14260      1   NaN       80
#
#   LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# 0         100    AllPub       100  ...        0    NaN   NaN           0
# 1         100    AllPub        40  ...        0    NaN   NaN           0
# 2         100    AllPub       100  ...        0    NaN   NaN           0
# 3         100    AllPub        80  ...        0    NaN   NaN           0
# 4         100    AllPub        40  ...        0    NaN   NaN           0
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0       0      2    2008        20             50     208500
# 1       0      5    2007        20             50     181500
# 2       0      9    2008        20             50     223500
# 3       0      2    2006        20            100     140000
# 4       0     12    2008        20             50     250000
#
# [5 rows x 80 columns]

# %%
meanTest = test_df.mean(axis=0)
test_df=test_df-meanTest
sd=test_df.std(axis=0)


test_array_norm=test_df/(sd+0.0000001)

print(test_array_norm.shape)
# Out:
# (1459, 79)
# <ipython-input-62-fbfdb5222621>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   meanTest = test_df.mean(axis=0)

# %%
meanTrain = train_df.mean(axis=0)
train_df=train_df-meanTrain
sd=train_df.std(axis=0)


train_array_norm=train_df/(sd+0.0000001)

print(train_array_norm.shape)
# Out:
# (1460, 80)
# <ipython-input-63-f82b9e826aa9>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   meanTrain = train_df.mean(axis=0)

# %%
from sklearn.model_selection import train_test_split
features = train_array_norm.drop('SalePrice', axis=1)
labels = train_array_norm['SalePrice']
x_train, x_test, y_train, y_test = train_test_split(features, labels, test_size=0.1, random_state=42, shuffle=True)

# %%
def loss(y_pred,y_true):
  m = len(y_true)
  return np.sum((y_pred - y_true)**2) / (2 * m)

# %%
def y(x,a,b):
  """
  This function should return predicted value of y = ax+b
  input:
  x: [array] the feature vector of shape (m,n)
  a: [array] weights of shape (n,)
  b: [scalar] bias

  output:
  y_pred: [array] predicted value of y of shape (m,)
  """
  return np.dot(x, a) + b

# %%
import sympy as sp
def gradient(x,a,b,y_true):
    m = len(y_true)
    y_pred = y(x, a, b)

    da = np.dot(x.T, (y_pred - y_true)) / m
    db = np.sum(y_pred - y_true) / m

    return da, db

# %%
x_train['a'] = np.random.rand(len(x_train))

# %%
def gradient_descent(x,y_true,learning_rate=0.01,epochs = 10):

    n = x.shape
    a = np.zeros(n[1])  # Initialize weights
    b = 0            # Initialize bias

    loss_mse = []  # Initialize empty list to store loss

    for i in range(0,epochs):
        da, db = gradient(x, a, b, y_true)
        a = a - learning_rate * da
        b = b - learning_rate * db

        y_pred = y(x, a, b)
        l_mse = loss(y_pred, y_true)
        loss_mse.append(l_mse)

        print("Epoch", i + 1, "completed! Loss =", l_mse)

    print("Training completed!")

    assert a.shape == (n[1],)

    return loss_mse,a,b

# %%
epochs = 1000          # tweak this!!!
learn_rate = 0.00001          # choose learning rate wisely otherwise loss may diverge!!

train_loss,a,b = gradient_descent(x_train,y_train,learn_rate,epochs)
# Out:
# Epoch 1 completed! Loss = 0.0
# Epoch 2 completed! Loss = 0.0
# Epoch 3 completed! Loss = 0.0
# Epoch 4 completed! Loss = 0.0
# Epoch 5 completed! Loss = 0.0
# Epoch 6 completed! Loss = 0.0
# Epoch 7 completed! Loss = 0.0
# Epoch 8 completed! Loss = 0.0
# Epoch 9 completed! Loss = 0.0
# Epoch 10 completed! Loss = 0.0
# Epoch 11 completed! Loss = 0.0
# Epoch 12 completed! Loss = 0.0
# Epoch 13 completed! Loss = 0.0
# Epoch 14 completed! Loss = 0.0
# Epoch 15 completed! Loss = 0.0
# Epoch 16 completed! Loss = 0.0
# Epoch 17 completed! Loss = 0.0
# Epoch 18 completed! Loss = 0.0
# Epoch 19 completed! Loss = 0.0
# Epoch 20 completed! Loss = 0.0
# Epoch 21 completed! Loss = 0.0
# Epoch 22 completed! Loss = 0.0
# Epoch 23 completed! Loss = 0.0
# Epoch 24 completed! Loss = 0.0
# Epoch 25 completed! Loss = 0.0
# Epoch 26 completed! Loss = 0.0
# Epoch 27 completed! Loss = 0.0
# Epoch 28 completed! Loss = 0.0
# Epoch 29 completed! Loss = 0.0
# Epoch 30 completed! Loss = 0.0
# Epoch 31 completed! Loss = 0.0
# Epoch 32 completed! Loss = 0.0
# Epoch 33 completed! Loss = 0.0
# Epoch 34 completed! Loss = 0.0
# Epoch 944 completed! Loss = 0.0
# Epoch 945 completed! Loss = 0.0
# Epoch 946 completed! Loss = 0.0
# Epoch 947 completed! Loss = 0.0
# Epoch 948 completed! Loss = 0.0
# Epoch 949 completed! Loss = 0.0
# Epoch 950 completed! Loss = 0.0
# Epoch 951 completed! Loss = 0.0
# Epoch 952 completed! Loss = 0.0
# Epoch 953 completed! Loss = 0.0
# Epoch 954 completed! Loss = 0.0
# Epoch 955 completed! Loss = 0.0
# Epoch 956 completed! Loss = 0.0
# Epoch 957 completed! Loss = 0.0
# Epoch 958 completed! Loss = 0.0
# Epoch 959 completed! Loss = 0.0
# Epoch 960 completed! Loss = 0.0
# Epoch 961 completed! Loss = 0.0
# Epoch 962 completed! Loss = 0.0
# Epoch 963 completed! Loss = 0.0
# Epoch 964 completed! Loss = 0.0
# Epoch 965 completed! Loss = 0.0
# Epoch 966 completed! Loss = 0.0
# Epoch 967 completed! Loss = 0.0
# Epoch 968 completed! Loss = 0.0
# Epoch 969 completed! Loss = 0.0
# Epoch 970 completed! Loss = 0.0
# Epoch 971 completed! Loss = 0.0
# Epoch 972 completed! Loss = 0.0
# Epoch 973 completed! Loss = 0.0
# Epoch 974 completed! Loss = 0.0
# Epoch 975 completed! Loss = 0.0
# Epoch 976 completed! Loss = 0.0
# Epoch 977 completed! Loss = 0.0
# Epoch 978 completed! Loss = 0.0
# Epoch 979 completed! Loss = 0.0
# Epoch 980 completed! Loss = 0.0
# Epoch 981 completed! Loss = 0.0
# Epoch 982 completed! Loss = 0.0
# Epoch 983 completed! Loss = 0.0
# Epoch 984 completed! Loss = 0.0
# Epoch 985 completed! Loss = 0.0
# Epoch 986 completed! Loss = 0.0
# Epoch 987 completed! Loss = 0.0
# Epoch 988 completed! Loss = 0.0
# Epoch 989 completed! Loss = 0.0
# Epoch 990 completed! Loss = 0.0
# Epoch 991 completed! Loss = 0.0
# Epoch 992 completed! Loss = 0.0
# Epoch 993 completed! Loss = 0.0
# Epoch 994 completed! Loss = 0.0
# Epoch 995 completed! Loss = 0.0
# Epoch 996 completed! Loss = 0.0
# Epoch 997 completed! Loss = 0.0
# Epoch 998 completed! Loss = 0.0
# Epoch 999 completed! Loss = 0.0
# Epoch 1000 completed! Loss = 0.0
# Training completed!

# %%
test_loss = loss(y(x_test, a, b).reshape((146,)), y_test.reshape((146,)))

print("Loss on test data = ",test_loss)

# Visualization of loss
y=train_loss
x=epochs

plt.plot(x,y,label='Traning loss vs Epochs')                   # plot loss versus epochs
plt.title("Training Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-66cec3f50a18> in <cell line: 1>()
# ----> 1 test_loss = loss(y(x_test, a, b).reshape((146,)), y_test.reshape((146,)))
#       2
#       3 print("Loss on test data = ",test_loss)
#       4
#       5 # Visualization of loss
#
# <ipython-input-72-6903d366beb8> in y(x, a, b)
#      10   y_pred: [array] predicted value of y of shape (m,)
#      11   """
# ---> 12   return np.dot(x, a) + b
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in dot(*args, **kwargs)
#
# ValueError: shapes (146,79) and (80,) not aligned: 79 (dim 1) != 80 (dim 0)
